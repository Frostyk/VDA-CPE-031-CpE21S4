# %% [markdown]
# <a href="https://colab.research.google.com/github/KennJieValleser/VDA-CPE-031-CpE21S4/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,8])
ypoints=np.array([3,20])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# Plotting without line
# To plot only the markers 'o' means

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints,marker='p')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'o:r')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*:r',ms=20)
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*:r',ms=20, mec='b')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*:r',ms=20, mec='b',mfc='yellow')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*r',ms=20, mec='b',mfc='yellow', linestyle='--')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*r',ms=20, mec='b',mfc='yellow', linestyle='--')

plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*r',ms=20, mec='b',mfc='yellow', linestyle='--')

plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid()
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*r',ms=20, mec='b',mfc='yellow', linestyle='--')

plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='y')
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'*r',ms=20, mec='b',mfc='yellow', linestyle='--')

plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='x',linestyle='--',linewidth=0.50)
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(xpoints,ypoints)
plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")

xpoints=np.array([1,2,6,8])
ypoints=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(xpoints,ypoints)
plt.title("Distance Travelled Everyday", color='r')
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='x',linestyle='--',linewidth=0.50)
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.scatter(ypoints,xpoints)


xpoints=np.array([1,2,6,8])
ypoints=np.array([10,20,30,40])

plt.scatter(ypoints,xpoints)
plt.grid(axis='x',linestyle='--',linewidth=0.50)
plt.show()

# %%
import numpy as np

x=np.array(['Student1','Student2','Student3'])
y=np.array([90,85,86])

plt.bar(x,y)
plt.show()

# %%
import numpy as np



g=np.array([35,25,25,15])
grader=['Grade 1=35%','Grade 2=25%','Grade 3=25%','Grade 4=15%']
plt.pie(g,labels=grader)
plt.legend(title='Grader')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/KennJieValleser/VDA-CPE-031-CpE21S4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **VDA what is data analysis**

# %% [markdown]
# **Types of Data Analysis**
#
# Descriptive Analysis- is the most common and primary forms of data analysis. It is used to find the "what is/has happening/happened?" in business. Usually, we take to help descriptive data analysis to track the *Key Performance Indicator*(KPI), sales profits/loss

# %%
import pandas as pd
data= {'apples':[3,2,0,1],'oranges':[0,3,7,2]}
purchases= pd.DataFrame(data, index=['June','Robert','Lily','David'])

purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')

# %%
purchases.to_excel('fruits.xlsx')

# %%
from google.colab import files
#uploaded= files.upload()

data=pd.read_csv('fruits.csv')
purchases=pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data=pd.read_excel('fruits.xlsx')
purchases=pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data.head(2)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3

# %%
data.tail(2)
# Out:
#   Unnamed: 0  apples  oranges
# 2       Lily       0        7
# 3      David       1        2

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-17e1dccb-2833-43a4-86bd-aaff36cc1a78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e1dccb-2833-43a4-86bd-aaff36cc1a78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data=pd.read_csv('hsr_character-data.csv')
data
# Out:
#         character  rarity          path combat_type  wb_b-atk  wb_skill  \
# 0       march_7th       4  preservation         ice        30         0
# 1        dan_heng       4          hunt        wind        30        60
# 2          himeko       5     erudition        fire        30        60
# 3            welt       5      nihility   imaginary        30        30
# 4           kafka       5      nihility   lightning        30        60
# 5     silver_wolf       5      nihility     quantum        30        60
# 6           arlan       4   destruction   lightning        30        60
# 7            asta       4       harmony        fire        30        30
# 8           herta       4     erudition         ice        30        30
# 9          bronya       5       harmony        wind        30         0
# 10          seele       5          hunt     quantum        30        60
# 11         serval       4     erudition   lightning        30        60
# ...

# %%
data = pd.read_csv('hsr_character-data.csv')

data_dict = {
    'Name': data['character'].tolist(),
    'Path': data['path'].tolist(),
    'Combat Type': data['combat_type'].tolist(),
    'HP at lvl 80': data['hp_80'].tolist(),
    'ATK at lvl 80': data['atk_80'].tolist(),
    'DEF at lvl 80': data['def_80'].tolist(),
}

new_df = pd.DataFrame(data_dict)


print(new_df)
# Out:
#              Name          Path Combat Type  HP at lvl 80  ATK at lvl 80  \
# 0       march_7th  preservation         ice       1058.00         511.56
# 1        dan_heng          hunt        wind        882.00         546.84
# 2          himeko     erudition        fire       1048.00         756.76
# 3            welt      nihility   imaginary       1125.43         620.93
# 4           kafka      nihility   lightning       1086.62         679.14
# 5     silver_wolf      nihility     quantum       1047.82         640.33
# 6           arlan   destruction   lightning       1199.52         599.76
# 7            asta       harmony        fire       1023.00         511.56
# 8           herta     erudition         ice        953.00         582.12
# 9          bronya       harmony        wind       1242.00         582.12
# 10          seele          hunt     quantum        931.00         640.33
# 11         serval     erudition   lightning        917.00         652.68
# ...

# %%
import pandas as pd
data = pd.read_csv('hsr_character-data.csv')
data = [{'character': 'Trailblazer (Physical)', 'path': 'Destruction', 'combat_type': 'Physical', 'hp_80': 1203, 'atk_80': 620.93, 'def_80': 460.84},
        {'character': 'Trailblazer (Fire)', 'path': 'Preservation', 'combat_type': 'Fire', 'hp_80': 1242, 'atk_80': 601.52, 'def_80': 606.37},
        {'character': 'Seele', 'path': 'The Hunt', 'combat_type': 'Quantum', 'hp_80': 931, 'atk_80': 640.33, 'def_80':  363.83 },
        {'character': 'Himeko', 'path': 'Erudition', 'combat_type': 'Fire', 'hp_80': 1048, 'atk_80': 756.76, 'def_80': 436.59},
        {'character': 'Welt', 'path': 'Nihility', 'combat_type': 'Imaginary', 'hp_80': 1125.43, 'atk_80': 620.93, 'def_80': 509.36},
        ]

df = pd.DataFrame(data)

print(df)
# Out:
#                 character          path combat_type    hp_80  atk_80  def_80
# 0  Trailblazer (Physical)   Destruction    Physical  1203.00  620.93  460.84
# 1      Trailblazer (Fire)  Preservation        Fire  1242.00  601.52  606.37
# 2                   Seele      The Hunt     Quantum   931.00  640.33  363.83
# 3                  Himeko     Erudition        Fire  1048.00  756.76  436.59
# 4                    Welt      Nihility   Imaginary  1125.43  620.93  509.36

# %%
column = df['character']

print(column)
# Out:
# 0    Trailblazer (Physical)
# 1        Trailblazer (Fire)
# 2                     Seele
# Name: character, dtype: object

# %%
twocolumns = df[['character', 'path']]

print(twocolumns)
# Out:
#                 character          path
# 0  Trailblazer (Physical)   Destruction
# 1      Trailblazer (Fire)  Preservation
# 2                   Seele      The Hunt

# %%
single_row = df.loc[0]
print(single_row)
# Out:
# character      Trailblazer (Physical)
# path                      Destruction
# combat_type                  Physical
# hp_80                           12584
# atk_80                            992
# def_80                            677
# Name: 0, dtype: object

# %%
multiple_rows = df.loc[0:2]
print(multiple_rows)
# Out:
#                 character          path combat_type  hp_80  atk_80  def_80
# 0  Trailblazer (Physical)   Destruction    Physical  12584     992     677
# 1      Trailblazer (Fire)  Preservation        Fire  13716     919     769
# 2                   Seele      The Hunt     Quantum  11360    1094     633
